# %%
# Import Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the dataset
df = pd.read_excel('DQN1 Dataset.xlsx')

# %%
# Take the first look at the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetimeEpoch    1000 non-null   float64
#  1   tempmax          1000 non-null   float64
#  2   tempmin          1000 non-null   float64
#  3   temp             1000 non-null   float64
#  4   feelslikemax     1000 non-null   float64
#  5   feelslikemin     1000 non-null   float64
#  6   feelslike        1000 non-null   float64
#  7   pm2.5            1000 non-null   float64
#  8   no2              1000 non-null   float64
#  9   co2              1000 non-null   float64
#  10  dew              1000 non-null   float64
#  11  humidity         1000 non-null   float64
#  12  precip           1000 non-null   float64
#  13  precipprob       1000 non-null   float64
#  14  precipcover      1000 non-null   float64
#  15  windgust         1000 non-null   float64
#  16  windspeed        1000 non-null   float64
#  17  winddir          1000 non-null   float64
#  18  pressure         1000 non-null   float64
#  19  cloudcover       1000 non-null   float64
#  20  visibility       1000 non-null   float64
#  21  solarradiation   1000 non-null   float64
#  22  solarenergy      1000 non-null   float64
#  23  uvindex          1000 non-null   float64
#  24  severerisk       1000 non-null   float64
#  25  sunriseEpoch     1000 non-null   float64
#  26  sunsetEpoch      1000 non-null   float64
#  27  moonphase        1000 non-null   float64
#  28  tempRange        1000 non-null   float64
#  29  heatIndex        1000 non-null   float64
#  30  severityScore    1000 non-null   float64
#  31  month            1000 non-null   int64
#  32  dayOfWeek        1000 non-null   int64
#  33  isWeekend        1000 non-null   bool
#  34  healthRiskScore  1000 non-null   float64
# dtypes: bool(1), float64(32), int64(2)
# memory usage: 266.7 KB

# %%
# Prepare data for model
X = df.drop('healthRiskScore', axis=1)
y = df['healthRiskScore']
# Split data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=7) # 30% test, 70% training

# %%
# Create the model
lr_model = LinearRegression()

# Fit the model
lr_model.fit(X_train, y_train)

# Predict using the model
y_pre = lr_model.predict(X_test)
